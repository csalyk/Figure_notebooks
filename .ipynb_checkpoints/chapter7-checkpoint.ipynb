# %%
# %pylab inline
import pandas as pd
from matplotlib.patches import Ellipse
from astropy.constants import c,h,k_B,au
import pickle as pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Re-define your data and (output) figure directories here:

# %%
data_dir='/Users/csalyk/Dropbox/ASTR230_lecture_notes/Figure_notebooks/data/'
fig_dir='/Users/csalyk/Dropbox/ASTR230_lecture_notes/Manuscript/Figures/'

# %% [markdown]
# ### Define default plot parameters

# %%
rcParams['axes.linewidth'] = 2 # set the value globally
plt.rc('font', family='serif')

# %% [markdown]
# ## Figure 7.10b: Reflectance spectra

# %%
#RELab data
olivine_file=data_dir+'c1sc02.txt'
pyroxene_file=data_dir+'c1pp09.txt'
plagioclase_file=data_dir+'c1dh11.txt'

spec_olivine=np.recfromtxt(olivine_file,names=['wave','reflectance'],skip_header=2)
spec_pyroxene=np.recfromtxt(pyroxene_file,names=['wave','reflectance'],skip_header=2)
spec_plagioclase=np.recfromtxt(plagioclase_file,names=['wave','reflectance','sd'],skip_header=2)

fig=plt.figure(figsize=(10,4))
ax1=fig.add_subplot(111)
ax1.plot(spec_olivine['wave'],spec_olivine['reflectance'],label='Olivine',color='green',lw=3)
ax1.plot(spec_pyroxene['wave'],spec_pyroxene['reflectance'],label='Pyroxene (Diopside)',color='black',lw=3,linestyle='--')
ax1.plot(spec_plagioclase['wave'],spec_plagioclase['reflectance'],label='Plagioclase Feldspar (Bytownite)',color='Orange',lw=3,linestyle='-.')
ax1.set_xlim(0.,3.5)
ax1.legend(handlelength=4)
for tick in ax1.xaxis.get_major_ticks():
    tick.label1.set_fontsize(16)
    tick.label1.set_fontweight('medium')
for tick in ax1.yaxis.get_major_ticks():
    tick.label1.set_fontsize(16)
    tick.label1.set_fontweight('medium')
ax1.set_ylabel('Reflectance',fontsize=18)
ax1.set_xlabel('Wavelength [$\mu$m]',fontsize=18)

fig.savefig(fig_dir+'Fig07x10b.eps',bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Wavelength [$\\mu$m]')
